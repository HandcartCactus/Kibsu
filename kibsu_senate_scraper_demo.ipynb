# %% [markdown]
# # kibsu
# > ## kibsu (Akkadian)
# >
# > [Transport → Surface]
# >
# > a footprint... a trail , a path , a route... a way of calculation... a line of reasoning...
#
# _[`Kibsu` on assyrianlanguages.org](https://www.assyrianlanguages.org/akkadian/dosearch.php?searchkey=7840&language=id)_
#
# Kibsu is an experimental high-level HTML/XML scraping framework in Python that allows you to scrape with semantics, not div classes. It is based on Xpath, but provides some added advantages:
# 1. Readability
# 2. DRY Compositional Logic
# 3. Higher-level logic
# 4. Cross-site reusability (with luck!)
#
# The ultimate **goal** of Kibsu is to write a single scraper and deploy it across many sites with different HTML but similar content.
#
# For this demo, we will scrape the following sites, which all have a similar semantic structure (dates and links) but have differing HTML and CSS classes, making them laborious to scrape.
#
# + https://www.markey.senate.gov/news/press-releases
# + https://www.young.senate.gov/newsroom/press-releases/
# + https://www.mcconnell.senate.gov/public/index.cfm/pressreleases
# + https://www.crapo.senate.gov/media/newsreleases
# + https://www.wyden.senate.gov/news/blog

# %%
press_release_urls = [
    "https://www.markey.senate.gov/news/press-releases",
    "https://www.young.senate.gov/newsroom/press-releases/",
    "https://www.mcconnell.senate.gov/public/index.cfm/pressreleases",
    "https://www.crapo.senate.gov/media/newsreleases",
    "https://www.wyden.senate.gov/news/blog",
]

# %% [markdown]
# ## Resolvers
# The building block of Kibsu is the `Resolver`. A `Resolver` always has these properties:
# 1. The method `resolve`, which takes in an LXML etree element and returns a value of `Any` type. This is the function that extracts the value of interest from the XML/HTML.
# 2. The method `does_resolve`, which takes in an LXML etree element and returns a `bool`. This method tells Kibsu if the resolver was able to find any matches of interest. The function `does_resolve` can just check if the function `resolve` returns null or errors, but it can also do more than that, including data validation, etc.
# 4. An `include` property, which tells Kibsu whether or not the value from `resolve` should be included in output.
# 5. A `resolver_type` property with the name of the type of the resolver.
#
# Resolvers are very flexible, and can even be composed. Here is a composed `Resolver` which looks for the first link which is a descendant of the current element:

# %%
from core import HasDescendantResolver, LinkOrFragmentResolver


has_descendant_with_link = HasDescendantResolver(
        {
            'link': LinkOrFragmentResolver(),
        }
    )

# %% [markdown]
# Resolvers can do logic and take arbitary functions. This composition of resolvers finds a descendant of your current element containing a date in one of three different date formats. The `resolve` method will call one of the `date_format_to_iso_parser`s and return an ISO format date string like this: `{'pub_date': '2024-03-08T00:00:00'}`.

# %%
from core import FunctionResolver, OneSubResolver, date_format_to_iso_parser


has_descendant_with_date = HasDescendantResolver(
    resolvers = {
        'pub_date': OneSubResolver(
            resolvers = {
                '%B %d, %Y': FunctionResolver(date_format_to_iso_parser('%B %d, %Y')),
                '%m/%d/%y': FunctionResolver(date_format_to_iso_parser('%m/%d/%y')),
                '%A, %B %d, %Y': FunctionResolver(date_format_to_iso_parser('%A, %B %d, %Y')),
            }
        ),
    },
)

# %% [markdown]
# The real fun begins with `DeepestResolver`, a resolver which `does_resolve` if it has children which resolve the sub-`Resolver`s, but none of the children themselves `do_resolve` all of the sub-`Resolver`s. As a consequence, `DeepestResolver` `does_resolve` on the deepest part of the element tree which has your pattern of interest, allowing you to collect lots of resolutions of interest, easily.

# %%
from core import DeepestResolver


press_release = DeepestResolver(
    resolvers={
        "link_descendant": has_descendant_with_link,
        "date_descendant": has_descendant_with_date,
    },
    children_only=True,
)

# %% [markdown]
# ## Kibsu (The Class)
# Just like that, we've almost written a working press release scraper for several senators, without even looking at the specific html on their websites. The scraper works on all three of these sites, even though they have different HTML and classes.

# %%
from core import Kibsu

get_press_releases = Kibsu(
    resolvers={"press_release": press_release},
)

# %%
from lxml import etree
import requests
from pprint import pprint

all_press_releases = []
for url in press_release_urls:
        
        print(url)

        r = requests.get(url)
        tree = etree.ElementTree(etree.HTML(r.content))
        press_releases = get_press_releases(tree)
        all_press_releases.extend(press_releases)
        pprint(press_releases[2])
# Out:
# https://www.markey.senate.gov/news/press-releases
# {'press_release': {'date_descendant': {'pub_date': '2024-03-15T00:00:00'},
#                    'link_descendant': {'link': {'text': 'Markey, Merkley, '
#                                                         'Colleagues: Don’t '
#                                                         'Leave Flight Crews '
#                                                         'Behind, Protect '
#                                                         'Workers’ Right to '
#                                                         'Pump at Work',
#                                                 'url': 'https://www.markey.senate.gov/news/press-releases/markey-merkley-colleagues-dont-leave-flight-crews-behind-protect-workers-right-to-pump-at-work'}}}}
# https://www.young.senate.gov/newsroom/press-releases/
# {'press_release': {'date_descendant': {'pub_date': '2024-03-13T00:00:00'},
#                    'link_descendant': {'link': {'text': 'Young, Colleagues '
#                                                         'Demand the Biden '
#                                                         'Administration '
#                                                         'Increase Agricultural '
#                                                         'Exports',
#                                                 'url': 'https://www.young.senate.gov/newsroom/press-releases/young-colleagues-demand-the-biden-administration-increase-agricultural-exports/'}}}}
# https://www.mcconnell.senate.gov/public/index.cfm/pressreleases
# {'press_release': {'date_descendant': {'pub_date': '2024-03-14T00:00:00'},
#                    'link_descendant': {'link': {'text': 'Democrats Continue '
#                                                         'Partisan Attacks On '
#                                                         'Federal Judiciary',
#                                                 'url': '/public/index.cfm/pressreleases?ID=A9540629-F13E-4980-AC0B-746E2233564A'}}}}
# https://www.crapo.senate.gov/media/newsreleases
# {'press_release': {'date_descendant': {'pub_date': '2024-03-14T00:00:00'},
#                    'link_descendant': {'link': {'text': '',
#                                                 'url': 'https://www.crapo.senate.gov/media/newsreleases/crapo-joins-bill-blocking-bidens-misguided-forestry-plan'}}}}
# https://www.wyden.senate.gov/news/blog
# {'press_release': {'date_descendant': {'pub_date': '2022-06-22T00:00:00'},
#                    'link_descendant': {'link': {'text': 'Loud & Proud – Pride '
#                                                         'Prevails Over '
#                                                         'Prejudice',
#                                                 'url': 'https://www.wyden.senate.gov/news/blog/loud-and-proud_pride-prevails-over-prejudice'}}}}

# %%
from core import FlatMapper

flat_mapper = FlatMapper({
    'date': ['press_release', 'date_descendant', 'pub_date'],
    'link_url': ['press_release', 'link_descendant', 'link', 'url'],
    'link_text': ['press_release', 'link_descendant', 'link', 'text'],
})
pprint([flat_mapper(pr) for pr in all_press_releases])
# Out:
# [{'date': '2024-03-15T00:00:00',
#   'link_text': 'Senator Markey, Sunrise Movement Talk the Power of Organizing, '
#                'American Climate Corps on Latest Episode of the “The Ed Markey '
#                'Podcast”',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/senator-markey-sunrise-movement-talk-the-power-of-organizing-american-climate-corps-on-latest-episode-of-the-the-ed-markey-podcast'},
#  {'date': '2024-03-15T00:00:00',
#   'link_text': 'Markey, Schumer, Colleagues Demand MOHELA Remedy Harms to '
#                'Millions of Borrowers Following Egregious Business Practices',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/markey-schumer-colleagues-demand-mohela-remedy-harms-to-millions-of-borrowers-following-egregious-business-practices'},
#  {'date': '2024-03-15T00:00:00',
#   'link_text': 'Markey, Merkley, Colleagues: Don’t Leave Flight Crews Behind, '
#                'Protect Workers’ Right to Pump at Work',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/markey-merkley-colleagues-dont-leave-flight-crews-behind-protect-workers-right-to-pump-at-work'},
#  {'date': '2024-03-14T00:00:00',
#   'link_text': 'Butler, Smith Introduce Pride in Mental Health Act to Support '
#                'Lgbtq+ Youth',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/butler-smith-introduce-pride-in-mental-health-act-to-support-lgbtq-youth'},
#  {'date': '2024-03-14T00:00:00',
#   'link_text': 'Durbin, Lee Introduce Bipartisan Safe Act to Reform FISA '
#                'Section 702',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/durbin-lee-introduce-bipartisan-safe-act-to-reform-fisa-section-702'},
#  {'date': '2024-03-14T00:00:00',
#   'link_text': 'Senator Markey, Congressman Lieu Commend FCC Vote to '
#                'Greenlight Cyber Trust Mark Program',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/senator-markey-congressman-lieu-commend-fcc-vote-to-greenlight-cyber-trust-mark-program'},
#  {'date': '2024-03-13T00:00:00',
#   'link_text': 'Markey, Foster, Merkley Introduce Bicameral Resolution to '
#                'Bolster Nuclear Arms Control Regimes',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/markey-foster-merkley-introduce-bicameral-resolution-to-bolster-nuclear-arms-control-regimes'},
#  {'date': '2024-03-13T00:00:00',
#   'link_text': 'Senator Markey Leads Colleagues in Bipartisan Investigation '
#                'into the Role of Private Equity in Restricting Access to '
#                'Methadone Treatment for Opioid Use Disorder',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/senator-markey-leads-colleagues-in-bipartisan-investigation-into-the-role-of-private-equity-in-restricting-access-to-methadone-treatment-for-opioid-use-disorder'},
#  {'date': '2024-03-13T00:00:00',
#   'link_text': 'Markey Joins Sanders, 19 Colleagues in Letter to Postmaster '
#                'General DeJoy Demanding Protection of Jobs and Mail Delivery',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/markey-joins-sanders-19-colleagues-in-letter-to-postmaster-general-dejoy-demanding-protection-of-jobs-and-mail-delivery'},
#  {'date': '2024-03-12T00:00:00',
#   'link_text': 'Senator Markey Statement on Resignation of Prime Minister '
#                'Henry, Ongoing Violence in Haiti',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/senator-markey-statement-on-resignation-of-prime-minister-henry-ongoing-violence-in-haiti'},
#  {'date': '2024-03-12T00:00:00',
#   'link_text': 'Senator Markey’s Pre-Development Provisions Advance in Senate '
#                'Committee Passage of Economic Development Administration '
#                'Reauthorization Act',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/senator-markeys-pre-development-provisions-advance-in-senate-committee-passage-of-economic-development-administration-reauthorization-act'},
#  {'date': '2024-03-12T00:00:00',
#   'link_text': 'Markey, McGovern Applaud National Park Service for Heeding '
#                'Calls to Evaluate Deerfield River for Protection',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/markey-mcgovern-applaud-national-park-service-for-heeding-calls-to-evaluate-deerfield-river-for-protection'},
#  {'date': '2024-03-12T00:00:00',
#   'link_text': 'Markey Joins Hirono, Peters, Pressley, Colleagues in '
#                'Introducing Resolution Recognizing Abortion Providers',
#   'link_url': 'https://www.markey.senate.gov/news/press-releases/markey

#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-touts-positive-impact-of-the-chips-and-science-act-on-u-s-economy-competitiveness/'},
#  {'date': '2024-03-08T00:00:00',
#   'link_text': 'Young, Colleagues Expand Investigation of Sanctuary Airports',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-colleagues-expand-investigation-of-sanctuary-airports/'},
#  {'date': '2024-03-07T00:00:00',
#   'link_text': 'Young, Colleagues Lead Effort to Establish U.S. Artificial '
#                'Intelligence Safety Institute',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-colleagues-lead-effort-to-establish-us-artificial-intelligence-safety-institute/'},
#  {'date': '2024-03-05T00:00:00',
#   'link_text': 'PHOTOS: Young Visits Liberation Labs in Richmond as Part of '
#                '“Made in Indiana” Tour',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/photos-young-visits-liberation-labs-in-richmond-as-part-of-made-in-indiana-tour/'},
#  {'date': '2024-03-04T00:00:00',
#   'link_text': 'Young, Colleagues Demand EPA Rescind Job-Killing Air Quality '
#                'Standards',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-colleagues-demand-epa-rescind-job-killing-air-quality-standards/'},
#  {'date': '2024-03-01T00:00:00',
#   'link_text': 'Young Joins Amicus Brief to SCOTUS Case Challenging the FDA '
#                'Deregulation of Chemical Abortion Drugs',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-joins-amicus-brief-to-scotus-case-challenging-the-fda-deregulation-of-chemical-abortion-drugs/'},
#  {'date': '2024-02-29T00:00:00',
#   'link_text': 'Young Celebrates Vermillion County Bicentennial on Senate '
#                'Floor',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-celebrates-vermillion-county-bicentennial-on-senate-floor/'},
#  {'date': '2024-02-28T00:00:00',
#   'link_text': 'Young Joins Amicus Brief Supporting Pro-Life SCOTUS Case',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-joins-amicus-brief-supporting-pro-life-scotus-case/'},
#  {'date': '2024-02-27T00:00:00',
#   'link_text': 'Young Presses Biden Administration on Houthi Attacks, Need for '
#                'Strategy to Deter Iran’s Destabilizing Actions',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-presses-biden-administration-on-houthi-attacks-need-for-strategy-to-deter-irans-destabilizing-actions/'},
#  {'date': '2024-02-26T00:00:00',
#   'link_text': 'Young, Colleagues Introduce Resolution Highlighting Importance '
#                'of U.S.-ROK-Japan Trilateral Cooperation',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-colleagues-introduce-resolution-highlighting-importance-of-us-rok-japan-trilateral-cooperation/'},
#  {'date': '2024-02-23T00:00:00',
#   'link_text': 'PHOTOS: Young, National Security Commission on Emerging '
#                'Biotechnology Hold Indiana Events',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/photos-young-national-security-commission-on-emerging-biotechnology-hold-indiana-events/'},
#  {'date': '2024-02-22T00:00:00',
#   'link_text': 'Young, Colleagues Ask EPA to Appeal Arizona Dicamba Decision',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-colleagues-ask-epa-to-appeal-arizona-dicamba-decision/'},
#  {'date': '2024-02-21T00:00:00',
#   'link_text': 'Young, Colleagues Call On Administration to Improve '
#                'Communication about Federal Paid Leave Policies',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-colleagues-call-on-administration-to-improve-communication-about-federal-paid-leave-policies/'},
#  {'date': '2024-02-16T00:00:00',
#   'link_text': 'Young, Coons Resolution Establishing National FFA Week Passes '
#                'Senate',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-coons-resolution-establishing-national-ffa-week-passes-senate/'},
#  {'date': '2024-02-15T00:00:00',
#   'link_text': 'Growing Momentum for the Kids Online Safety Act: Young, '
#                'Colleagues Announce Over 60 Cosponsors and Supporters',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/growing-momentum-for-the-kids-online-safety-act-young-colleagues-announce-over-60-cosponsors-and-supporters/'},
#  {'date': '2024-02-15T00:00:00',
#   'link_text': 'Young, Colleagues Demand “Coherent and Complete Response” On '
#                'Anti-Catholic FBI Memo',
#   'link_url': 'https://www.young.senate.gov/newsroom/press-releases/young-colleagues-demand-coherent-and-complete-response-on-anti-catholic-fbi-memo/'},
#  {'date': '2024-03-14T00:00:00',
#   'link_text': 'Leader McConnell Leads Congressional Effort to Push Back on '
#                'EPA’s Regulatory Overkill',
#   'link_url': '/public/index.cfm/pressreleases?ID=56855CB7-61F3-4250-AC14-025CF4809E99'},
#  {'date': '2024-03-14T00:00:00',
#   'link_text': 'McConnell Defends Israeli Democracy And Sovereignty',
#   'link_url': '/public/index.cfm/pressreleases?ID=4ED2C387-4705-4C31-A53B-3F9E72715A2A'},
#  {'date': '2024-03-14T00:00:00',
#   'link_text': 'Democrats Continue Partisan Attacks On Federal Judiciary',
#   'link_url': '/public/index.cfm/pressreleases?ID=A9540629-F13E-4980-AC0B-746E2233564A'},
#  {'date': '2024-03-14T00:00:00',
#   'link_text': 'McConnell: Withholding Aid To Ukraine Emboldens Putin',
#   'link_url': '/public/index.cfm/pressreleases?ID=0F520299-8784-411C-AEFE-90B192FBA8A3'},
#  {'date': '2024-03-14T00:00:00',
#   'link_text': 'New EPA Biden Admin. Standard Would Hurt Kentucky, Increase '
#                'Dependency On China',
#   'link_url': '/public/index.cfm/pressreleases?ID=668FDF07-822A-48F9-992F-C14E6A7D74CB'},
#  {'date': '2024-03-12T00:00:00',
#   'link_text': 'Biden Admin. Budget: Wartime Taxes, But Neglect For Defense',
#   'link_url': '/public/index.cfm/pressreleases?ID=D50D94E3-8950-4831-8882-0B9132E1F7BD'},
#  {'date': '2024-03-12T00:00:00',
#   'link_text': 'Biden Admin. Scrambles To Save Radical Nominee',
#   'link_url': '/public/index.cfm/pressreleases?ID=6EBDA275-E0DB-4CC0-8851-19068389D2F6'},
#  {'date': '2024-03-11T00:00:00',
#   'link_text': 'McConnell Secures Critical Resources for Kentucky as Senate '
#                'Advances Major Portion of Government Funding',
#   'link_url': '/public/index.cfm/pressreleases?ID=B0C7647F-94BE-44E7-9230-116C056A30E7'},
#  {'date': '2024-03-11T00:00:00',
#   'link_text': 'McConnell Secures Resources to Benefit West Kentucky in '
#                'Government Funding Bill',
#   'link_url': '/public/index.cfm/pressreleases?ID=E72EAFDA-B52A-488F-8A98-0B87E05A8C30'},
#  {'date': '2024-03-11T00:00:00',
#   'link_text': 'McConnell: Proud To Welcome Newest NATO Allies',
#   'link_url': '/public/index.cfm/pressreleases?ID=D8C1BA59-626D-4927-8D1D-08B9DB508AD3'},
#  {'date': '2024-03-11T00:00:00',
#   'link_text': 'Senate Takes Aim at Biden Administration’s Latest '
#                'One-Size-Fits-All Mandate',
#   'link_url': '/public/index.cfm/pressreleases?ID=D0EC77E1-663B-4A72-81A4-645752A34251'},
#  {'date': '2024-03-08T00:00:00',
#   'link_text': 'McConnell Secures Critical Resources for Kentucky’s Military '
#                'Installations and Servicemembers',
#   'link_url': '/public/index.cfm/pressreleases?ID=5464A9FD-2986-4E61-8291-629C9B690199'},
#  {'date': '2024-03-08T00:00:00',
#   'link_text': 'McConnell Secures Resources to Benefit Kentucky in Government '
#                'Funding Bill',
#   'link_url': '/public/index.cfm/pressreleases?ID=7E81846D-01E7-4D94-B15E-01DB48E2E9DF'},
#  {'date': '2024-03-08T00:00:00',
#   'link_text': 'Senate Confirms Kentuckian as Member of the National '
#                'Transportation Safety Board',
#   'link_url': '/public/index.cfm/pressreleases?ID=3D29BF5C-462F-4C73-8731-9B46F3E51DD2'},
#  {'date': '2024-03-07T00:00:00',
#   'link_text': 'McConnell Comments on President Biden’s State of the Union '
#                'Address and Senator Britt’s Response',
#   'link_url': '/public/index.cfm/pressreleases?ID=2B04CC11-BCC1-4B52-A0DA-B997332E505F'},
#  {'date': '2024-03-07T00:00:00',
#   'link_text': 'McConnell On The State Of The Union: President Failing Most '
#                'Basic Responsibilities Of Government',
#   'link_url': '/public/index.cfm/pressreleases?ID=75E1D300-712E-4957-87EA-A02FD7C8EC95'},
#  {'date': '2024-03-06T00:00:00',
#   'link_text': 'McConnell Marks 45th Anniversary Of Taiwan Relations Act',
#   'link_url': '/public/index.cfm/pressreleases?ID=68A330D4-B8ED-4F94-884C-970341F92D7B'},
#  {'date': '2024-03-06T00:00:00',
#   'link_text': 'Prescription Drug Socialism Raises Costs, Reduces Treatments, '
#                'Kills Jobs',
#   'link_url': '/public/index.cfm/pressreleases?ID=F4B6EA77-C99D-4D07-AC29-4C4172733CED'},
#  {'date': '2024-03-05T00:00:00',
#   'link_text': 'Law Enforcement Sounds Alarm On Radical Judicial Nominee',
#   'link_url': '/public/index.cfm/pressreleases?ID=276D653B-FCD6-4E3E-9BB0-9CA8F867BD18'},
#  {'date': '2024-03-05T00:00:00',
#   'link_text': 'McConnell On Annual Appropriations',
#   'link_url': '/public/index.cfm/pressreleases?ID=AA2F6306-92EA-43C6-A97B-A479C100F0A9'},
#  {'date': '2024-02-29T00:00:00',
#   'link_text': 'McConnell On Government Funding And National Security '
#                'Priorities',
#   'link_url': '/public/index.cfm/pressreleases?ID=48C150C4-6867-43BE-B88B-23F0DB2499C0'},
#  {'date': '2024-02-28T00:00:00',
#   'link_text': 'McConnell Remarks On Last Term As Republican Leader',
#   'link_url': '/public/index.cfm/pressreleases?ID=EA41ADEE-43E5-47EB-BBE1-0A23B6CBF7C1'},
#  {'date': '2024-02-28T00:00:00',
#   'link_text': 'Joint Statement on FY24 Appropriations Agreement',
#   'link_url': '/public/index.cfm/pressreleases?ID=32A0F294-759F-490C-8171-50322F57C6A2'},
#  {'date': '2024-02-28T00:00:00',
#   'link_text': 'Biden’s LNG Ban Baffles Allies, Pleases Adversaries',
#   'link_url': '/public/index.cfm/pressreleases?ID=43C76C9D-9714-4C22-AA9C-838C6CEF3B4D'},
#  {'date': '2024-02-28T00:00:00',
#   'link_text': 'McConnell: ‘Stop Providing Taxpayer Subsidies To Institutions '
#                'That Have Clearly Lost Their Grip On Reality’',
#   'link_url': '/public/index.cfm/pressreleases?ID=181155FC-34D7-4731-BA33-7DEBC277D595'},
#  {'date': '2024-03-14T00:00:00',
#   'link_text': '',
#   'link_url': 'https://www.crapo.senate.gov/media/newsreleases/crapo-wyden-call-for-swift-passage-of-bipartisan-pbm-reforms'},
#  {'date': '2024-03-14T00:00:00',
#   'link_text': '',
#   'link_url': 'https://www.crapo.senate.gov/media/newsreleases/crapo-hhs-budget-fails-to-deliver-on-key-promises-for-americans'},
#  {'date': '2024-03-14T00:00:00',
#   'link_text': '',
#   'link_url': 'https://www.crapo.senate.gov/media/newsreleases/crapo